# %%
import pandas as pd
import requests
import json

# %%
## arranjar uma forma de obter o número total de issues de um repositório

'''
response = requests.get('https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues?per_page=100&state=all')
data = response.json()
issues = pd.DataFrame(data)


for i in range():
    page = 2
    response = requests.get('https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues?per_page=100&state=all&page=' + str(page))
    data_new = response.json()
    issues_new = pd.DataFrame(data_new)
    issues = pd.concat([issues, issues_new])
    page += 1

issues
'''

# %%
response = requests.get('https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues?per_page=100&state=all&sort=comments')
issues = pd.DataFrame(response.json())
issues
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/freeCodeCamp/free...
# 1   https://api.github.com/repos/freeCodeCamp/free...
# 2   https://api.github.com/repos/freeCodeCamp/free...
# 3   https://api.github.com/repos/freeCodeCamp/free...
# 4   https://api.github.com/repos/freeCodeCamp/free...
# ..                                                ...
# 95  https://api.github.com/repos/freeCodeCamp/free...
# 96  https://api.github.com/repos/freeCodeCamp/free...
# 97  https://api.github.com/repos/freeCodeCamp/free...
# 98  https://api.github.com/repos/freeCodeCamp/free...
# 99  https://api.github.com/repos/freeCodeCamp/free...
#
#                                        repository_url  \
# 0   https://api.github.com/repos/freeCodeCamp/free...
# 1   https://api.github.com/repos/freeCodeCamp/free...
# 2   https://api.github.com/repos/freeCodeCamp/free...
# 3   https://api.github.com/repos/freeCodeCamp/free...
# ...

# %%
## todos os comentários das 4 issues mais comentadas

comments = pd.DataFrame()

for i in range(5):
    if isinstance(issues.pull_request.iloc[i], float):
        number = issues.number.iloc[i]
        for j in range(1, issues.comments.iloc[i]//100 + 2):
            response = requests.get(f'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues/{number}/comments?per_page=100&page={j}')
            data = response.json()
            comments_new = pd.DataFrame(data)
            comments = pd.concat([comments, comments_new])

comments.reset_index(drop=True, inplace=True)

# %%
comments
# Out:
#                                                    url  \
# 0    https://api.github.com/repos/freeCodeCamp/free...
# 1    https://api.github.com/repos/freeCodeCamp/free...
# 2    https://api.github.com/repos/freeCodeCamp/free...
# 3    https://api.github.com/repos/freeCodeCamp/free...
# 4    https://api.github.com/repos/freeCodeCamp/free...
# ..                                                 ...
# 405  https://api.github.com/repos/freeCodeCamp/free...
# 406  https://api.github.com/repos/freeCodeCamp/free...
# 407  https://api.github.com/repos/freeCodeCamp/free...
# 408  https://api.github.com/repos/freeCodeCamp/free...
# 409  https://api.github.com/repos/freeCodeCamp/free...
#
#                                               html_url  \
# 0    https://github.com/freeCodeCamp/freeCodeCamp/i...
# 1    https://github.com/freeCodeCamp/freeCodeCamp/i...
# 2    https://github.com/freeCodeCamp/freeCodeCamp/i...
# 3    https://github.com/freeCodeCamp/freeCodeCamp/i...
# ...

# %%
comments = pd.DataFrame()

for number in issues['number'][:3]:
    response = requests.get(f'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues/{number}/comments?per_page=100')
    data = response.json()
    comments_new = pd.DataFrame(data)
    comments = pd.concat([comments, comments_new])

comments
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/freeCodeCamp/free...
# 1   https://api.github.com/repos/freeCodeCamp/free...
# 2   https://api.github.com/repos/freeCodeCamp/free...
# 3   https://api.github.com/repos/freeCodeCamp/free...
# 4   https://api.github.com/repos/freeCodeCamp/free...
# ..                                                ...
# 95  https://api.github.com/repos/freeCodeCamp/free...
# 96  https://api.github.com/repos/freeCodeCamp/free...
# 97  https://api.github.com/repos/freeCodeCamp/free...
# 98  https://api.github.com/repos/freeCodeCamp/free...
# 99  https://api.github.com/repos/freeCodeCamp/free...
#
#                                              html_url  \
# 0   https://github.com/freeCodeCamp/freeCodeCamp/i...
# 1   https://github.com/freeCodeCamp/freeCodeCamp/i...
# 2   https://github.com/freeCodeCamp/freeCodeCamp/i...
# 3   https://github.com/freeCodeCamp/freeCodeCamp/i...
# ...

# %%
from github import Github
from pprint import pprint

# %%
g = Github('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')
repo = g.get_repo("freeCodeCamp/freeCodeCamp")
issues = repo.get_issues(state="all", sort='comments')
lista = [issue for issue in issues]

# %%
g = Github('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')
repo = g.get_repo("freeCodeCamp/freeCodeCamp")
issues = repo.get_issues(state='all', sort='comments')

# %%
print(issues.get_page(0))
# Out:
# [Issue(title="TypeScript migration", number=42256), Issue(title="Migrate React-Redux Curriculum into FCC Codebase", number=16138), Issue(title="Deprecate Gitter rooms, Download all data", number=8418), Issue(title="Incorrect output for some equations - example javascript calculator project", number=10158), Issue(title="ES6: Create Strings using Template Literals - Test Fails - Doesn't detect template strings", number=16358), Issue(title="Chrome displays error message in iframe - Unsual code detected", number=13727), Issue(title="Timezone breaks submission: "cannot read `join` of null.", number=6633), Issue(title="Cursor jumps randomly in Code Editor.", number=7847), Issue(title="feat: unpack and repack challenges", number=16544), Issue(title="UI Components Library", number=41580), Issue(title="Contents of editor can not be reviewed by screen readers", number=12431), Issue(title="Test failing in: Applied Visual Design: Create a Horizontal Line Using the hr Element", number=17944), Iss
# ...

# %%
import requests
import os
from pprint import pprint

token = os.getenv('GITHUB_TOKEN', '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')
url = 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues?per_page=100&state=all'
headers = {'Authorization': f'token {token}'}
response = requests.get('https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues?per_page=100&state=all&sort=comments', headers=headers)

data = response.json()
df = pd.DataFrame(data)

# %%
token = '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'


authorization = f'token {token}'
headers = {"Accept": "application/vnd.github.v3+json",
            "Authorization" : authorization,
             }

url = 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues?per_page=100&state=all'
## headers = {'Authorization': f'token {token}'}
response = requests.get('https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues?per_page=100&state=all&sort=comments', headers=headers)

data = response.json()
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12980/3619127785.py in <module>
#      12
#      13 data = response.json()
# ---> 14 df = pd.DataFrame(data)
#
# c:\Users\PC\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# c:\Users\PC\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# ...

# %%
## arranjar uma forma de obter o número total de issues de um repositório

'''
response = requests.get('https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues?per_page=100&state=all')
data = response.json()
issues = pd.DataFrame(data)


for i in range():
    page = 2
    response = requests.get('https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues?per_page=100&state=all&page=' + str(page))
    data_new = response.json()
    issues_new = pd.DataFrame(data_new)
    issues = pd.concat([issues, issues_new])
    page += 1

issues
'''
